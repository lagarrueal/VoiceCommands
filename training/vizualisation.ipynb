# %%
import tensorflow as tf
from keras_visualizer import visualizer
# Out:
# 2023-02-09 16:31:47.074799: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-09 16:31:47.800051: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-09 16:31:47.800085: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
model = tf.keras.models.load_model('../models/model_cnn.h5')
# Out:
# 2023-02-09 16:31:56.181099: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-02-09 16:31:56.182551: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-09 16:31:56.183357: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Student-laptop): /proc/driver/nvidia/version does not exist
# 2023-02-09 16:31:56.187925: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resizing (Resizing)         (None, 32, 32, 1)         0
#
#  normalization (Normalizatio  (None, 32, 32, 1)        3
#  n)
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 128)               1605760
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 12)                1548
#
# ...
# Total params: 1,626,127
# Trainable params: 1,626,124
# Non-trainable params: 3
# _________________________________________________________________

# %%
model2 = tf.keras.models.Sequential(layers = [layer for layer in model.layers if not isinstance(layer, tf.keras.layers.Flatten)] )

# %%
import visualkeras
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=715x207>

# %%
tf.keras.utils.plot_model(model, show_layer_activations=True, show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96)
