# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# %%
dir = '../demo_kit/images/'
img_path = dir + 'go.png'
print(img_path)
# Out:
# ../demo_kit/images/go.png

# %%
os.listdir(dir)
# Out:
# ['yes.png',
#  'right.png',
#  'stop.png',
#  'down.png',
#  'off.png',
#  'go.png',
#  'left.png',
#  'no.png',
#  'up.png',
#  'on.png']

# %%
# plot an image from the directory dir
img = mpimg.imread(img_path)
plt.imshow(img)
plt.show()
